# %% [markdown]
# Изображаем статистические отношения
# =======Scatterplot (Точечный график)========

# %%
# Библиотека для работы с табличными данными
import pandas as pd
# Библиотека для вычислений линейной алгебры
import numpy as np
# Библиотеки для визуализации
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Начнем с чтения csv данных
df = pd.read_csv('california_housing_train.csv')

# %%
# Первые пять строк
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# Изображения точек долготы по отношению к широте.
# Можно заметить, что дома расположены в определенной "полосе" долготы и широты
plt.figure(figsize=(10, 7))
sns.scatterplot(data=df, x="longitude", y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
# Самостоятельная работа №1
# Изобразите отношение households к population
sns.scatterplot(data=df, x="households", y="population")
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sns.scatterplot(data=df, x="households", y="population",  hue="total_rooms")
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
# Самостоятельная работа №2
# Добавьте total_rooms используя дополнительное измерение size
sns.scatterplot(data=df, x="households", y="population",  hue="total_rooms")
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
cols = ['population', 'median_income', 'housing_median_age', 'median_house_value']
g = sns.PairGrid(df[cols])
g.map(sns.scatterplot)

# %%
cols = ['population', 'median_income', 'housing_median_age', 'median_house_value']
plt.figure(figsize=(10, 5))
g = sns.PairGrid(df[cols], corner=True)

g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %% [markdown]
# ======ЛИНЕЙНЫЕ ГРАФИКИ=======

# %%
# Для визуализации выбирается тип line
sns.relplot(x="latitude", y="median_house_value", kind="line", data=df)

# %%
# Самостоятельная работа №3
# Визуализировать longitude по отношения к median_house_value
# Используя линейный график
sns.relplot(x="longitude", y="median_house_value",  kind="line", data=df)

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x="latitude", y="longitude",  hue="median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# =======ГИСТОГРАММА========

# %%
sns.histplot(data=df, x="median_income")
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %%
# Самостоятельная работа №5
# Изобраить гистограмму по housing_median_age
sns.histplot(data=df, x="housing_median_age")
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df[df['housing_median_age']>50], x="median_income")
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %%
sns.histplot(data=df, x="population", binwidth=1000)
# Out:
# <Axes: xlabel='population', ylabel='Count'>

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.loc[df['housing_median_age'] <= 20, 'age_group'] = 'Молодые'
df.loc[(df['housing_median_age'] > 20) & (df['housing_median_age'] <= 50), 'age_group'] = 'Ср. возраст'
df.loc[df['housing_median_age'] > 50, 'age_group'] = 'Пожилые'
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13576\2697177954.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Молодые' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['housing_median_age'] <= 20, 'age_group'] = 'Молодые'

# %%
df.head(30)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
# 12    -114.61     34.84                48.0       1291.0           248.0
# 13    -114.61     34.83                31.0       2478.0           464.0
# 14    -114.63     32.76                15.0       1448.0           378.0
# 15    -114.65     34.89                17.0       2556.0           587.0
# 16    -114.65     33.60                28.0       1678.0           322.0
# 17    -114.65     32.79                21.0         44.0            33.0
# 18    -114.66     32.74                17.0       1388.0           386.0
# 19    -114.67     33.92                17.0         97.0            24.0
# 20    -114.68     33.49                20.0       1491.0           360.0
# 21    -114.73     33.43                24.0        796.0           243.0
# 22    -114.94     34.55                20.0        350.0            95.0
# 23    -114.98     33.82                15.0        644.0           129.0
# 24    -115.22     33.54                18.0       1706.0           397.0
# 25    -115.32     32.82                34.0        591.0           139.0
# 26    -115.37     32.82                30.0       1602.0           322.0
# 27    -115.37     32.82                14.0       1276.0           270.0
# 28    -115.37     32.81                32.0        741.0           191.0
# 29    -115.37     32.81                23.0       1458.0           294.0
#
#     population  households  median_income  median_house_value    age_group
# 0       1015.0       472.0         1.4936             66900.0      Молодые
# 1       1129.0       463.0         1.8200             80100.0      Молодые
# 2        333.0       117.0         1.6509             85700.0      Молодые
# 3        515.0       226.0         3.1917             73400.0      Молодые
# 4        624.0       262.0         1.9250             65500.0      Молодые
# 5        671.0       239.0         3.3438             74000.0  Ср. возраст
# 6       1841.0       633.0         2.6768             82400.0  Ср. возраст
# 7        375.0       158.0         1.7083             48500.0  Ср. возраст
# 8       3134.0      1056.0         2.1782             58400.0  Ср. возраст
# 9        787.0       271.0         2.1908             48100.0  Ср. возраст
# 10      2434.0       824.0         2.6797             86500.0      Молодые
# 11      1182.0       437.0         1.6250             62000.0  Ср. возраст
# 12       580.0       211.0         2.1571             48600.0  Ср. возраст
# 13      1346.0       479.0         3.2120             70400.0  Ср. возраст
# 14       949.0       300.0         0.8585             45000.0      Молодые
# 15      1005.0       401.0         1.6991             69100.0      Молодые
# 16       666.0       256.0         2.9653             94900.0  Ср. возраст
# 17        64.0        27.0         0.8571             25000.0  Ср. возраст
# 18       775.0       320.0         1.2049             44000.0      Молодые
# 19        29.0        15.0         1.2656             27500.0      Молодые
# 20      1135.0       303.0         1.6395             44400.0      Молодые
# 21       227.0       139.0         0.8964             59200.0  Ср. возраст
# 22       119.0        58.0         1.6250             50000.0      Молодые
# 23       137.0        52.0         3.2097             71300.0      Молодые
# 24      3424.0       283.0         1.6250             53500.0      Молодые
# 25       327.0        89.0         3.6528            100000.0  Ср. возраст
# 26      1130.0       335.0         3.5735             71100.0  Ср. возраст
# 27       867.0       261.0         1.9375             80900.0      Молодые
# 28       623.0       169.0         1.7604             68600.0  Ср. возраст
# 29       866.0       275.0         2.3594             74300.0  Ср. возраст

# %%
df.groupby('age_group')['median_income'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='age_group'>

# %%
df.loc[df['median_income'] > 6, 'income_group'] = 'rich'
df.loc[df['median_income'] < 6, 'income_group'] = 'everyone_else'
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13576\410380823.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'rich' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['median_income'] > 6, 'income_group'] = 'rich'

# %%
sns.displot(df, x="median_house_value", hue="income_group")

# %%
# Самостоятельная работа
# Изобразить гистограмму по median_house_value с оттенком age_group
sns.displot(df, x="median_house_value", hue="age_group")

# %% [markdown]
# =======Самостоятельная работа=========
# Написать EDA для датасета про пингвинов
#
# Необходимо:
# Использовать 2-3 точечных графика
# Применить доп измерение в точечных графиках, используя аргументы hue, size, stile
# Использовать PairGrid с типом графика на ваш выбор
# Изобразить Heatmap
# Использовать 2-3 гистограммы

# %%
penguins = sns.load_dataset("penguins")

# %%
p = sns.load_dataset("titanic")

# %%
p.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1 = p.loc[p['survived'] == 1, ['sex']]

# %%
df1.head(20)
# Out:
#        sex
# 1   female
# 2   female
# 3   female
# 8   female
# 9   female
# 10  female
# 11  female
# 15  female
# 17    male
# 19  female
# 21    male
# 22  female
# 23    male
# 25  female
# 28  female
# 31  female
# 32  female
# 36    male
# 39  female
# 43  female

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Первые 5 строк датасета про пингвинов
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
display(data)
# Out:
#    whoAmI
# 0   human
# 1   robot
# 2   human
# 3   robot
# 4   robot
# 5   human
# 6   human
# 7   human
# 8   robot
# 9   human
# 10  robot
# 11  robot
# 12  human
# 13  human
# 14  robot
# 15  human
# 16  robot
# 17  human
# 18  robot
# 19  robot

# %%
import pandas as pd
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
one_hot = pd.get_dummies(data['whoAmI'])
data = pd.concat([data, one_hot], axis=1)
data.head()
# Out:
#   whoAmI  human  robot
# 0  robot  False   True
# 1  human   True  False
# 2  robot  False   True
# 3  human   True  False
# 4  robot  False   True
